# %%
import os
import time
import pandas as pd
import akshare as ak
import warnings
from datetime import timedelta, datetime
warnings.filterwarnings("ignore")
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('expand_frame_repr', False)
pd.set_option('display.unicode.ambiguous_as_wide', True)
pd.set_option('display.unicode.east_asian_width', True)

# %%
code_list = pd.read_csv('CodeList.csv')

# %%
stock_individual_info_em_df = ak.stock_individual_info_em(symbol="000001")
stock_individual_info_em_df.rename(columns = {'总市值':'Total_Value','行业':'Stock_Industry'},inplace=True)
stock_individual_info_em_df
# Out:
#        item                value
# 0    总市值  195999773799.799988
# 1  流通市值       195996024195.0
# 2      行业                 银行
# 3  上市时间             19910403
# 4  股票代码               000001
# 5  股票简称             平安银行
# 6    总股本        19405918198.0
# 7    流通股        19405546950.0

# %%
stock_individual_info_em_df['value'][0]
# Out:
# 195999773799.8

# %%
df = pd.DataFrame(columns=['Stock_ID', 'Stock_Name', 'Stock_Industry', 'Stock_Industry_Prev',
                           'Stock_Market','Stock_Code','Total_Value','Total_Value_Prev'])

# %%
import pandas as pd
#df = pd.DataFrame(columns=['Stock_ID', 'Stock_Name', 'Stock_Industry', 'Stock_Industry_Prev',
#                           'Stock_Market','Stock_Code','Total_Value','Total_Value_Prev'])
x=0
for CodeDes in code_list.values:
    ak_code, ak_name = CodeDes[1],CodeDes[2]
    print(ak_code,ak_name)
    if ak_code[2:] in set(df['Stock_ID']):
        print(True)
        continue
    stock_individual_info_em_df = ak.stock_individual_info_em(symbol=ak_code[2:])
   
    data = {
        'Stock_ID': ak_code[2:],
        'Stock_Name': ak_name, 
        'Stock_Industry': stock_individual_info_em_df['value'][2], 
        'Stock_Industry_Prev': None,
        'Stock_Market': 'CN',
        'Stock_Code': ak_code,
        'Total_Value': stock_individual_info_em_df['value'][0],
        'Total_Value_Prev': 0
    }
    
    #df = df.append(data) append removed from pandas 2.0 or higher
    df.loc[len(df)] = data
# Out:
# bj430017 星昊医药
# True
# bj430047 诺思兰德
# True
# bj430090 同辉信息
# True
# bj430139 华岭股份
# True
# bj430198 微创光电
# True
# bj430300 辰光医疗
# True
# bj430418 苏轴股份
# True
# bj430425 乐创技术
# True
# bj430476 海能技术
# True
# bj430478 峆一药业
# True
# bj430489 佳先股份
# True
# bj430510 丰光精密
# True
# bj430556 雅达股份
# True
# bj430564 天润科技
# True
# bj430685 新芝生物
# True
# bj430718 合肥高科
# True
# bj830779 武汉蓝电
# True
# bj830799 艾融软件
# True
# bj830809 安达科技
# True
# bj830832 齐鲁华信
# True
# bj830839 万通液压
# True
# bj830879 基康仪器
# True
# bj830896 旺成科技
# True
# bj830946 森萱医药
# True
# bj830964 润农节水
# True
# bj830974 凯大催化
# True
# bj831010 凯添燃气
# True
# bj831039 国义招标
# True
# bj831087 秋乐种业
# True
# bj831152 昆工科技
# True
# bj831167 鑫汇科
# True
# bj831195 三祥科技
# True
# bj831278 泰德股份
# True
# bj831304 迪尔化工
# True
# bj831305 海希通讯
# True
# bj831370 新安洁
# True
# bj831445 龙竹科技
# True
# bj831526 凯华材料
# True
# bj831627 力王股份
# True
# bj831641 格利尔
# True
# bj831689 克莱特
# True
# bj831726 朱老六
# True
# bj831768 拾比佰
# True
# bj831832 科达自控
# ...

# %%
df.to_csv('Dim_Stock.csv',index=False,encoding='gbk')

# %%
df[:10]
# Out:
#   Stock_ID Stock_Name Stock_Industry Stock_Industry_Prev Stock_Market Stock_Code   Total_Value  Total_Value_Prev
# 0   430017   星昊医药       化学制药                None           CN   bj430017  2.015169e+09                 0
# 1   430047   诺思兰德       生物制品                None           CN   bj430047  4.818258e+09                 0
# 2   430090   同辉信息       软件开发                None           CN   bj430090  7.554741e+08                 0
# 3   430139   华岭股份         半导体                None           CN   bj430139  3.559112e+09                 0
# 4   430198   微创光电     计算机设备                None           CN   bj430198  8.697513e+08                 0
# 5   430300   辰光医疗       医疗器械                None           CN   bj430300  7.657564e+08                 0
# 6   430418   苏轴股份       通用设备                None           CN   bj430418  2.048530e+09                 0
# 7   430425   乐创技术       软件开发                None           CN   bj430425  6.460293e+08                 0
# ...
